# %%
from bs4 import BeautifulSoup
import requests
import time

# %%
from selenium import webdriver

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
h = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36'}

# %%
res = requests.get('https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=487081506#params%5BplylstSeq%5D=487081506&po=pageObj&startIndex=51', headers=h)

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
li = soup.select('tbody')[0].select('tr')

# %%
for i in li:
    title = i.select('div.rank01')[0].text.strip()
    singer = i.select('div.rank02')[0].select('span')[0].text
    print(f"{title} - {singer}")
# Out:
# 이별 공식 - R.ef
# 머피의 법칙 - DJ DOC
# 말해줘 - 지누션
# 사나이 가는 길 (폼생폼사) - 젝스키스
# 천생연분 - 솔리드
# 한 (Come A Come) - 샤크라
# Come Back Home - 서태지와 아이들
# 날개 잃은 천사 - 룰라
# 배반의 장미 - 엄정화
# 고요속의 외침 - R.ef
# 그녀와의 이별 - 김현정
# 3!4! - 룰라
# Twist King - 터보
# 스피드 - 김건모
# 일과 이분의 일 - 투투
# 꿍따리 샤바라 - 클론
# Gimme! Gimme! - 컨츄리 꼬꼬
# 질투 - 영턱스클럽
# Emotion - 유채영
# Love Is... (3+3=0) - 터보
# 정 (위험한 이별) - 영턱스클럽
# 현명한 선택 - 소찬휘
# 순정 (純情) - 코요태
# 늑대와 함께 춤을 - 임창정
# Doc와 춤을 - DJ DOC
# 할 수 있어 - 엔알지 (NRG)
# 왜불러 - 디바
# Honey - 박진영
# 애상 - 쿨 (COOL)
# ('Cause) I'm Your Girl - S.E.S.
# 너는 왜 - 철이와 미애
# 삐에로는 우릴 보고 웃지 (Remake) - 김완선
# 성숙 - 스페이스 에이
# 영원한 사랑 - 핑클 (Fin.K.L)
# 이브의 경고 - 박미경
# 일심 (一心) - 컨츄리 꼬꼬
# 만남 - 코요태

# %%
# Out:
# C:\Users\bitcamp\anaconda3\envs\py37_env\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
dic = {'title': [], 'singer': []}
driver = webdriver.Chrome('data_files/chromedriver.exe')
for x in range(2):
    num = 1 + (50*x)
    driver.get(f"https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=427968315#params%5BplylstSeq%5D=427968315&po=pageObj&startIndex={num}")
    time.sleep(2)
    text = driver.page_source
    soup = BeautifulSoup(text, 'html.parser')
    li = soup.select('tbody')[0].select('tr')
    for i in li:
        title = i.select('div.rank01')[0].text.strip()
        singer = i.select('div.rank02')[0].select('span')[0].text
        dic['title'].append(title)
        dic['singer'].append(singer)
# Out:
# C:\Users\bitcamp\anaconda3\envs\py37_env\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %%
driver = webdriver.Chrome('data_files/chromedriver.exe')
driver.get(f"https://www.melon.com/mymusic/dj/mymusicdjplaylistview_inform.htm?plylstSeq=426635404")
time.sleep(2)
text = driver.page_source

soup = BeautifulSoup(text, 'html.parser')

li = soup.select('tbody')[0].select('tr')

dic = {'title': [], 'singer': []}
for i in li:
    title = i.select('div.rank01')[0].text.strip()
    singer = i.select('div.rank02')[0].select('span')[0].text
    dic['title'].append(title)
    dic['singer'].append(singer)
# Out:
# C:\Users\bitcamp\anaconda3\envs\py37_env\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   """Entry point for launching an IPython kernel.

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#                                   title                         singer
# 0                                  사실 난                         디어클라우드
# 1                        청춘 (Feat. 김창완)                             김필
# 2                                   클로즈                        못 (Mot)
# 3           내가 사랑한 모든 것들은 나를 눈물짓게 할 테니까                  모브닝 (MOVNING)
# 4                     어느 새(디깅클럽서울 Ver.)               백예린 (Yerin Baek)
# 5                                  Away  Collective Arts (콜렉티브아츠), 김현창
# 6                                  그런 밤                          어반자카파
# 7                          행복해 보이는 사람처럼                         빌리어코스티
# 8                                    어른                             이섭
# 9                        꽃 (Prod. 로코베리)                            윤미래
# 10                     놓아줘 (Let Me Out)                  종현 (JONGHYUN)
# 11                            I Am Blue                           1415
# ...

# %%
df.to_csv('감정별 플레이리스트/몽환.csv')

# %%
name_li = []
for file in file_li:
    name_li.append(file.replace('.csv', ''))

# %%
import os
file_li = os.listdir('감정별 플레이리스트')
for file in file_li:
    name = file.replace('.csv', '')
    globals()[f'df_{name}'] = pd.read_csv(f'감정별 플레이리스트/{file}').drop('Unnamed: 0', axis=1)

# %%
df_증오.title = df_증오.title.apply(lambda x: x.replace('19금\n', ''))

# %%
for name in name_li:
    globals()[f'df_{name}'].title = globals()[f'df_{name}'].title.apply(lambda x: x.replace('19금\n', ''))

# %%
df_기쁨2
# Out:
#                     title             singer
# 0                  Savior                김성규
# 1    Locked Inside A Door               드림캐쳐
# 2                With you            지민, 하성운
# 3               LOVE DIVE          IVE (아이브)
# 4           Shooting Star                남우현
# ..                    ...                ...
# 715               I Swear                씨스타
# 716                 CUPID  오마이걸 (OH MY GIRL)
# 717             Dumb Dumb  Red Velvet (레드벨벳)
# 718     유리구슬 (Glass Bead)     여자친구 (GFRIEND)
# 719                   아낀다                세븐틴
#
# [720 rows x 2 columns]

# %%
df = pd.DataFrame(columns = ['제목', '가수', '슬픔', '분노', '기쁨', '긴장감', '무서운', '증오', '차분히', '섹시', '브릿락', 
                       '설렘', '몽환'])

# %%
df_긴장감
# Out:
#                                                    제목               가수   슬픔  \
# 0                                               Alive              캐스커  NaN
# 1                                             Save me       leeSA (리싸)  NaN
# 2                                                 소나기               우효  NaN
# 3   (Bonus) What Are You Seeing? (Performance in f...             선우정아  NaN
# 4                                            Teardrop   Massive Attack  NaN
# 5                                                  안개         보아 (BoA)  NaN
# 6                                        Nobody Knows              김윤아  NaN
# 7                                  꽃이 지다  (Feat. 조원선)              정재형  NaN
# 8                                                 목소리              김윤아  NaN
# 9                                                  숨결   Mad Soul Child  NaN
# 10                                              그렇습니까               흐른  NaN
# ...

# %%
df_무서운 = pd.read_csv('감정별 플레이리스트/무서운.csv')

# %%
for i in df_무서운:
    print(i)
# Out:
# Unnamed: 0
# 제목
# 가수
# 슬픔
# 분노
# 기쁨
# 긴장감
# 무서운
# 증오
# 차분히
# 섹시
# 브릿락
# 설렘
# 몽환

# %%
df_차분함
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6848\3673916753.py in <module>
# ----> 1 df_차분히
#
# NameError: name 'df_차분히' is not defined

# %%
df = pd.DataFrame(columns = ['제목', '가수', '슬픔', '분노', '기쁨', '긴장감', '무서운', '증오', '차분히', '섹시', '브릿락', 
                       '설렘', '몽환'])    
df.제목 = df_몽환.title
df.가수 = df_몽환.singer
df.몽환 = 1
df_몽환 = df

# %%
df_몽환
# Out:
#                                      제목                             가수   슬픔  \
# 0                                  사실 난                         디어클라우드  NaN
# 1                        청춘 (Feat. 김창완)                             김필  NaN
# 2                                   클로즈                        못 (Mot)  NaN
# 3           내가 사랑한 모든 것들은 나를 눈물짓게 할 테니까                  모브닝 (MOVNING)  NaN
# 4                     어느 새(디깅클럽서울 Ver.)               백예린 (Yerin Baek)  NaN
# 5                                  Away  Collective Arts (콜렉티브아츠), 김현창  NaN
# 6                                  그런 밤                          어반자카파  NaN
# 7                          행복해 보이는 사람처럼                         빌리어코스티  NaN
# 8                                    어른                             이섭  NaN
# 9                        꽃 (Prod. 로코베리)                            윤미래  NaN
# 10                     놓아줘 (Let Me Out)                  종현 (JONGHYUN)  NaN
# ...

# %%
column_li = ['슬픔', '분노', '기쁨', '긴장감', '무서운', '증오', '차분히', '섹시', '브릿락', 
                       '설렘', '몽환']

# %%
df = pd.DataFrame()
for column in column_li:
    df = df.append(globals()[f"df_{column}"])

# %%
df.to_csv('data_files/플레이리스트.csv')

# %%
df_finale = df

# %%
pd.concat(df_기쁨)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6848\2501138675.py in <module>
# ----> 1 pd.concat(df_기쁨)
#
# ~\anaconda3\envs\py37_env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\py37_env\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     302         verify_integrity=verify_integrity,
#     303         copy=copy,
# --> 304         sort=sort,
#     305     )
#     306
#
# ...

# %%
df_기쁨 = df_기쁨.append(df_기쁨2)

# %%
df_기쁨.to_csv('감정별 플레이리스트/기쁨.csv')

# %%
name_li.remove('기쁨2')

# %%
name_li
# Out:
# ['기쁨', '긴장감', '몽환', '무서운', '분노', '브릿락', '설렘', '섹시', '슬픔', '증오', '차분함']

# %%
df_기쁨
# Out:
#                        title             singer
# 0                ...사랑했잖아...                  린
# 1                         가시                 버즈
# 2    나의 마음을 담아 ('달빛천사' 여는노래)                이용신
# 3               다시 사랑할 수 있을까     포맨 (4MEN), 박정은
# 4       Perhaps Love (사랑인가요)             하울, 제이
# ..                       ...                ...
# 715                  I Swear                씨스타
# 716                    CUPID  오마이걸 (OH MY GIRL)
# 717                Dumb Dumb  Red Velvet (레드벨벳)
# 718        유리구슬 (Glass Bead)     여자친구 (GFRIEND)
# 719                      아낀다                세븐틴
#
# [1450 rows x 2 columns]

# %%
pd.read_csv('감정별 플레이리스트/기쁨.csv')
# Out:
#       Unnamed: 0                    title             singer
# 0              0              ...사랑했잖아...                  린
# 1              1                       가시                 버즈
# 2              2  나의 마음을 담아 ('달빛천사' 여는노래)                이용신
# 3              3             다시 사랑할 수 있을까     포맨 (4MEN), 박정은
# 4              4     Perhaps Love (사랑인가요)             하울, 제이
# ...          ...                      ...                ...
# 1445         715                  I Swear                씨스타
# 1446         716                    CUPID  오마이걸 (OH MY GIRL)
# 1447         717                Dumb Dumb  Red Velvet (레드벨벳)
# 1448         718        유리구슬 (Glass Bead)     여자친구 (GFRIEND)
# 1449         719                      아낀다                세븐틴
#
# [1450 rows x 3 columns]
