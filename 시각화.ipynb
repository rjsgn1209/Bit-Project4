# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from bs4 import BeautifulSoup
import requests, re
from wordcloud import WordCloud

# %%
from konlpy.tag import Okt

# %%
df_word = pd.read_excel('data_files/감성사전_편집.xlsx')
df_word.set_index('Unnamed: 0', drop=True, inplace=True)

# %%
std_df = pd.read_csv('data_files/stopwords-ko.txt')

# %%
# url = 'https://novel.naver.com/webnovel/detail?novelId=994958&volumeNo=2' # 로맨스
# url = 'https://novel.naver.com/webnovel/detail?novelId=1002530&volumeNo=102' # 판타지
# url = 'https://novel.naver.com/webnovel/detail?novelId=927909&volumeNo=114' # 무협
# url = 'https://novel.naver.com/webnovel/detail?novelId=920928&volumeNo=1' # 현대

# %%
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

text = soup.select('div.detail_view_content')[0].text
text = ' '.join(re.compile('[ㄱ-ㅎ가-힣]+').findall(text))

okt = Okt()
okt_li = okt.morphs(text)
globals()['word_li'] = [i for i in okt_li if len(i) >= 2]
#word_li = [i for i in word_li if i not in std_df ]



mood_count = {'슬픔': 0,
'분노': 0,
'기쁨': 0,
'긴장감': 0,
'무서운': 0,
'증오': 0,
'차분히': 0,
'섹시': 0,
'브릿락': 0,
'설렘': 0,
'몽환': 0}
mood_words = {}
novel_word_counts = {}
for word in word_li:
    if word in df_word.index:
        word_mood = df_word.columns[df_word.loc[word, :] == 1].values[0]
        if word_mood in mood_words:
            mood_count[word_mood] += 1
            mood_words[word_mood].append(word)
        else:
            mood_count[word_mood] += 1
            mood_words[word_mood] =[word]
            
        if word in novel_word_counts:
            novel_word_counts[word] += 1
        else:
            novel_word_counts[word] = 1
for mood in mood_words.keys():
    mood_words[mood] = set(mood_words[mood])

novel_score = list(mood_count.values())

# %%
novel_word_counts
mood_words
# Out:
# {'슬픔': {'감정',
#   '걱정',
#   '무너지게',
#   '부정',
#   '불구',
#   '불행',
#   '사라져',
#   '실패',
#   '안색',
#   '어렵다',
#   '없다',
#   '절망',
#   '포기',
#   '피해',
#   '한숨',
#   '힘들다'},
#  '분노': {'고집',
#   '공격',
#   '덤벼',
#   '딱딱한',
#   '망할',
#   '빌어먹을',
#   '싸가지',
#   '싸우는',
#   '싸움',
#   '악착같이',
#   '재앙',
#   '죽인',
#   '파괴'},
#  '증오': {'끔찍한', '버리고', '새끼', '싫을', '짜증', '탐욕'},
#  '긴장감': {'급히',
#   '놀라',
#   '놀라서',
#   '놀랄',
#   '놀랍게도',
#   '당황',
#   '떨렸다',
#   '문제',
#   '움찔',
#   '중요한',
#   '폭발',
#   '한계',
#   '혼란'},
#  '무서운': {'거짓말', '공포', '괴물', '깨진', '위험', '저주', '황천'},
#  '몽환': {'바다', '바람', '비장', '빨리', '신경', '심장', '의식', '자는', '정신', '조심', '허망'},
#  '기쁨': {'간직',
#   '결심',
#   '귀한',
#   '도움',
#   '말쑥한',
#   '성공한',
#   '솜씨',
#   '승리',
#   '열정',
#   '열중',
#   '영웅',
#   '완성',
#   '용기',
#   '이익',
#   '자랑',
#   '젊은',
#   '정상',
#   '제일',
#   '특별한',
#   '해결'},
#  '브릿락': {'맞아', '아픈', '타격'},
#  '설렘': {'위력', '친절한', '친한'},
#  '차분히': {'망설이는', '안도'},
#  '섹시': {'가슴', '독한', '미친', '빠진', '흔들리는'}}

# %%
def novel_score_extract(url):
    res = requests.get(url)
    soup = BeautifulSoup(res.text, 'html.parser')

    text = soup.select('div.detail_view_content')[0].text
    text = ' '.join(re.compile('[ㄱ-ㅎ가-힣]+').findall(text))

    okt = Okt()
    okt_li = okt.morphs(text)
    globals()['word_li'] = [i for i in okt_li if len(i) >= 2]
    #word_li = [i for i in word_li if i not in std_df ]
    


    mood_count = {'슬픔': 0,
    '분노': 0,
    '기쁨': 0,
    '긴장감': 0,
    '무서운': 0,
    '증오': 0,
    '차분히': 0,
    '섹시': 0,
    '브릿락': 0,
    '설렘': 0,
    '몽환': 0}
    mood_words = {}

    for word in word_li:
        if word in df_word.index:
            word_mood = df_word.columns[df_word.loc[word, :] == 1].values[0]
            if word_mood in mood_words:
                mood_count[word_mood] += 1
                mood_words[word_mood].append(word)
            else:
                mood_count[word_mood] += 1
                mood_words[word_mood] =[word]
                
            
    for mood in mood_words.keys():
        mood_words[mood] = set(mood_words[mood])

    novel_score = list(mood_count.values())
    return novel_score

# %%
df_emotion = pd.read_csv('data_files/노래별감성점수_최종.csv')

# %%
emotion = df_emotion.drop(['Unnamed: 0', '노래', '가수'], axis=1)

# %%
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * (np.linalg.norm(b)))

# %%
def search_similarity(a):
    similarity_li = []
    for i in range(len(emotion)):
        b = emotion.iloc[i, :].values
        similarity_li.append(cosine_similarity(a, b))
    song_score = df_emotion.iloc[np.argmax(similarity_li), 3:].values
    title = df_emotion.iloc[np.argmax(similarity_li), 1]
    singer = df_emotion.iloc[np.argmax(similarity_li), 2]
    return f"{singer} - {title}", song_score

# %%
url = 'https://novel.naver.com/webnovel/detail?novelId=920928&volumeNo=1'
novel_score = novel_score_extract(url)
music, song_score = search_similarity(novel_score)
music
# Out:
# '김윤아 - 유리'

# %%
word_counts = {}
for i in word_li:
    if i in word_counts:
        word_counts[i] += 1
    else:
        word_counts[i] = 1

# %%
sorted(word_counts.items(), key = lambda item: item[1], reverse=True)
# Out:
# [('드래곤', 39),
#  ('오크', 26),
#  ('거북', 23),
#  ('했다', 23),
#  ('족장', 22),
#  ('으로', 22),
#  ('하지만', 16),
#  ('때문', 14),
#  ('이다', 13),
#  ('라텔', 12),
#  ('이었다', 11),
#  ('주술', 10),
#  ('하트', 9),
#  ('있었다', 9),
#  ('였다', 8),
#  ('하는', 8),
#  ('녀석', 7),
#  ('에게', 7),
#  ('모두', 7),
#  ('하고', 7),
#  ('존재', 7),
#  ('에서', 7),
#  ('까지', 7),
#  ('거대한', 6),
#  ('처럼', 6),
#  ('오웬', 6),
#  ('마법사', 6),
#  ('갑자기', 5),
#  ('시작', 5),
#  ('정신', 5),
#  ('됐다', 5),
#  ('모습', 5),
#  ('공격', 5),
#  ('정도', 5),
#  ('지금', 5),
#  ('공포', 5),
#  ('있던', 5),
#  ('원정', 5),
#  ('상황', 4),
#  ('에는', 4),
#  ('되는', 4),
#  ('생각', 4),
#  ('전사', 4),
#  ('없는', 4),
#  ('그리고', 4),
#  ('다른', 4),
#  ('결국', 4),
#  ('이라', 4),
#  ('마력', 4),
#  ('감정', 4),
#  ('얼굴', 4),
#  ('늙은', 4),
#  ('없었다', 4),
#  ('했으나', 3),
#  ('괴물', 3),
#  ('않고', 3),
#  ('마르', 3),
#  ('바다', 3),
#  ('돌격', 3),
#  ('세상', 3),
#  ('오거', 3),
#  ('로는', 3),
#  ('군대', 3),
#  ('크게', 3),
#  ('번개', 3),
#  ('움찔', 3),
#  ('그게', 3),
#  ('연기', 3),
#  ('다시', 3),
#  ('상대', 3),
#  ('하게', 3),
#  ('계속', 3),
#  ('보며', 3),
#  ('써야', 3),
#  ('그런', 3),
#  ('많은', 3),
#  ('물건', 3),
#  ('상자', 3),
#  ('의식', 3),
#  ('아니었다', 3),
#  ('주변', 3),
#  ('사로잡혔다', 3),
#  ('연결', 3),
#  ('그렇게', 3),
#  ('하지', 3),
#  ('불리는', 3),
#  ('대체', 3),
#  ('않았다', 3),
#  ('보다', 3),
#  ('이는', 3),
#  ('다크', 3),
#  ('엘프', 3),
#  ('합류', 3),
#  ('선실', 3),
#  ('인간', 3),
#  ('칼라', 3),
#  ('칼라쿠', 3),
#  ('거야', 3),
#  ('직접', 3),
#  ('정말', 3),
#  ('주문', 3),
#  ('루크', 3),
#  ('있다', 2),
#  ('라드', 2),
#  ('아쉬', 2),
#  ('같았다', 2),
#  ('나타난', 2),
#  ('모든', 2),
#  ('엉망', 2),
#  ('쿠우', 2),
#  ('다리', 2),
#  ('박살', 2),
#  ('있었으나', 2),
#  ('하나', 2),
#  ('미터', 2),
#  ('우르르', 2),
#  ('도끼', 2),
#  ('들고', 2),
#  ('죽인', 2),
#  ('대로', 2),
#  ('이름', 2),
#  ('포효', 2),
#  ('하며', 2),
#  ('내리', 2),
#  ('함께', 2),
#  ('등갑', 2),
#  ('머리', 2),
#  ('껍질', 2),
#  ('않은', 2),
#  ('고개', 2),
#  ('무슨', 2),
#  ('이번', 2),
#  ('만든', 2),
#  ('싸워야', 2),
#  ('판단', 2),
#  ('섰다', 2),
#  ('다르게', 2),
#  ('같이', 2),
#  ('당연히', 2),
#  ('화들짝', 2),
#  ('미친', 2),
#  ('사방', 2),
#  ('파도', 2),
#  ('몰랐다', 2),
#  ('중요한', 2),
#  ('결정', 2),
#  ('기껏', 2),
#  ('주교', 2),
#  ('육지', 2),
#  ('방법', 2),
#  ('상륙', 2),
#  ('해야', 2),
#  ('고민', 2),
#  ('하던', 2),
#  ('처음', 2),
#  ('밖에', 2),
#  ('내렸다', 2),
#  ('며칠', 2),
#  ('역시', 2),
#  ('물론', 2),
#  ('동원', 2),
#  ('하면', 2),
#  ('마침', 2),
#  ('그건', 2),
#  ('이기도', 2),
#  ('철제', 2),
#  ('부활', 2),
#  ('게다가', 2),
#  ('거지', 2),
#  ('타나', 2),
#  ('리스', 2),
#  ('에겐', 2),
#  ('신체', 2),
#  ('부위', 2),
#  ('어쩔', 2),
#  ('철컥', 2),
#  ('그것', 2),
#  ('가지', 2),
#  ('혈관', 2),
#  ('심장', 2),
#  ('동시', 2),
#  ('반응', 2),
#  ('쿠워', 2),
#  ('어어어어', 2),
#  ('반짝이는', 2),
#  ('발견', 2),
#  ('하고는', 2),
#  ('커다란', 2),
#  ('뻗은', 2),
#  ('거리', 2),
#  ('수가', 2),
#  ('않게', 2),
#  ('빨려', 2),
#  ('혈통', 2),
#  ('어깨', 2),
#  ('아아', 2),
#  ('나왔다', 2),
#  ('곧장', 2),
#  ('바로', 2),
#  ('에도', 2),
#  ('불구', 2),
#  ('방금', 2),
#  ('버렸다', 2),
#  ('아직', 2),
#  ('우연', 2),
#  ('보니', 2),
#  ('사이', 2),
#  ('한때', 2),
#  ('문제', 2),
#  ('마족', 2),
#  ('그리', 2),
#  ('저건', 2),
#  ('본디', 2),
#  ('자네', 2),
#  ('지하', 2),
#  ('유적', 2),
#  ('한데', 2),
#  ('마법', 2),
#  ('위스키', 2),
#  ('정상', 2),
#  ('젊은', 2),
#  ('약속', 2),
#  ('뭔가', 2),
#  ('으론', 1),
#  ('부정', 1),
#  ('명백했다', 1),
#  ('망할', 1),
#  ('탐내고', 1),
#  ('짜증', 1),
#  ('폭발', 1),
#  ('만들고', 1),
#  ('내지', 1),
#  ('다가왔다', 1),
#  ('해변', 1),
#  ('닿자', 1),
#  ('그야말로', 1),
#  ('지축', 1),
#  ('흔들리기', 1),
#  ('쿠웅', 1),
#  ('만이', 1),
#  ('감히', 1),
#  ('대항', 1),
#  ('아무리', 1),
#  ('용맹하다고', 1),
#  ('짜리', 1),
#  ('괴수', 1),
#  ('튀어나오면', 1),
#  ('얘기', 1),
#  ('다르다', 1),
#  ('물러나기', 1),
#  ('와중', 1),
#  ('몇몇', 1),
#  ('나간', 1),
#  ('금세', 1),
#  ('밟혀', 1),
#  ('피떡', 1),
#  ('삼나무', 1),
#  ('뽑기', 1),
#  ('갈락', 1),
#  ('맨손', 1),
#  ('투그', 1),
#  ('라도', 1),
#  ('당했다', 1),
#  ('나름', 1),
#  ('떨쳤던', 1),
#  ('들이었으나', 1),
#  ('본래', 1),
#  ('형체', 1),
#  ('죽었다', 1),
#  ('이대', 1),
#  ('싸워', 1),
#  ('보지', 1),
#  ('무너지게', 1),
#  ('생겼다', 1),
#  ('나섰다', 1),
#  ('비장', 1),
#  ('사용', 1),
#  ('번쩍여라', 1),
#  ('평야', 1),
#  ('꽂히는', 1),
#  ('매서운', 1),
#  ('외침', 1),
#  ('눈부신', 1),
#  ('빛과', 1),
#  ('낙뢰', 1),
#  ('작렬', 1),
#  ('정확히', 1),
#  ('때렸고', 1),
#  ('놀란', 1),
#  ('당황', 1),
#  ('했는지', 1),
#  ('움츠려', 1),
#  ('밀어', 1),
#  ('넣는다', 1),
#  ('전부', 1),
#  ('이익', 1),
#  ('에선', 1),
#  ('자욱하게', 1),
#  ('피어', 1),
#  ('오르고', 1),
#  ('타격', 1),
#  ('받지', 1),
#  ('태연히', 1),
#  ('내민다', 1),
#  ('이를', 1),
#  ('지켜본', 1),
#  ('아연', 1),
#  ('실색', 1),
#  ('해졌다', 1),
#  ('저딴', 1),
#  ('과거', 1),
#  ('일격', 1),
#  ('위력', 1),
#  ('만큼은', 1),
#  ('자타', 1),
#  ('공인', 1),
#  ('인데', 1),
#  ('하는지', 1),
#  ('어떤', 1),
#  ('생명력', 1),
#  ('구력', 1),
#  ('가진', 1),
#  ('없었기', 1),
#  ('망설이는', 1),
#  ('마음', 1),
#  ('용기', 1),
#  ('불어', 1),
#  ('넣었다', 1),
#  ('집어넣는', 1),
#  ('싸워야겠단', 1),
#  ('하라', 1),
#  ('간다', 1),
#  ('광기', 1),
#  ('가까운', 1),
#  ('열정', 1),
#  ('사로잡혀서', 1),
#  ('실로', 1),
#  ('무식하면', 1),
#  ('용감하단', 1),
#  ('맞았다', 1),
#  ('놀라', 1),
#  ('말리려', 1),
#  ('멈춰', 1),
#  ('이미', 1),
#  ('흥분해', 1),
#  ('버린', 1),
#  ('통제', 1),
#  ('불능', 1),
#  ('절망', 1),
#  ('빠졌다', 1),
#  ('보통', 1),
#  ('과는', 1),
#  ('차원', 1),
#  ('엄청난', 1),
#  ('희생', 1),
#  ('발생', 1),
#  ('앞발', 1),
#  ('찍자', 1),
#  ('십여', 1),
#  ('명의', 1),
#  ('터져', 1),
#  ('나갔다', 1),
#  ('재앙', 1),
#  ('피바다', 1),
#  ('물들었다', 1),
#  ('움직일', 1),
#  ('마다', 1),
#  ('수십', 1),
#  ('찌그러지거나', 1),
#  ('하늘', 1),
#  ('날아올랐다', 1),
#  ('강물', 1),
#  ('줄줄', 1),
#  ('흘렀고', 1),
#  ('밀려오는', 1),
#  ('섞여', 1),
#  ('온통', 1),
#  ('붉게', 1),
#  ('물들였다', 1),
#  ('물러나지', 1),
#  ('마라', 1),
#  ('그럼에도', 1),
#  ('덤벼', 1),
#  ('들었다', 1),
#  ('어쩌면', 1),
#  ('두렵기', 1),
#  ('더욱', 1),
#  ('악착같이', 1),
#  ('싸우는', 1),
#  ('건지도', 1),
#  ('갈림길', 1),
#  ('여기', 1),
#  ('잃으면', 1),
#  ('하기', 1),
#  ('힘들다', 1),
#  ('내려야', 1),
#  ('파괴', 1),
#  ('바람', 1),
#  ('가량', 1),
#  ('사라졌다', 1),
#  ('원체', 1),
#  ('귀한', 1),
#  ('만드는', 1),
#  ('이상', 1),
#  ('징발', 1),
#  ('하기도', 1),
#  ('어렵다', 1),
#  ('그렇다면', 1),
#  ('만으로', 1),
#  ('하는데', 1),
#  ('갈아', 1),
#  ('버릴', 1),
#  ('기세', 1),
#  ('빨리', 1),
#  ('한다', 1),
#  ('했던', 1),
#  ('없단', 1),
#  ('물리', 1),
#  ('하려면', 1),
#  ('동안', 1),
#  ('할지도', 1),
#  ('몰랐으니까', 1),
#  ('쫓아내는', 1),
#  ('제일', 1),
#  ('거대하기', 1),
#  ('먹히지', 1),
#  ('않는다', 1),
#  ('그렇다고', 1),
#  ('아니다', 1),
#  ('된다', 1),
#  ('그걸', 1),
#  ('해결', 1),
#  ('해줄', 1),
#  ('있기도', 1),
#  ('했고', 1),
#  ('아픈', 1),
#  ('저주', 1),
#  ('하겠다', 1),
#  ('심경', 1),
#  ('가져갔다', 1),
#  ('필요한', 1),
#  ('결코', 1),
#  ('싶지', 1),
#  ('않았으나', 1),
#  ('보존', 1),
#  ('해야만', 1),
#  ('노리', 1),
#  ('어차피', 1),
#  ('빼앗길', 1),
#  ('라면', 1),
#  ('쓰고', 1),
#  ('아군', 1),
#  ('이득', 1),
#  ('꼬이겠군', 1),
#  ('이긴', 1),
#  ('필수', 1),
#  ('이빨', 1),
#  ('이나', 1),
#  ('갈비뼈', 1),
#  ('여타', 1),
#  ('있기', 1),
#  ('다만', 1),
#  ('품은', 1),
#  ('걸리는', 1),
#  ('시간', 1),
#  ('달라진다', 1),
#  ('쓰면', 1),
#  ('이면', 1),
#  ('가능할', 1),
#  ('주가', 1),
#  ('소요', 1),
#  ('될지도', 1),
#  ('없지', 1),
#  ('결심', 1),
#  ('굳혔다', 1),
#  ('서둘러', 1),
#  ('잠금장치', 1),
#  ('풀었다', 1),
#  ('내용물', 1),
#  ('드러났는데', 1),
#  ('부서진', 1),
#  ('수정', 1),
#  ('덩어리', 1),
#  ('생긴', 1),
#  ('뻗어있는', 1),
#  ('알려주고', 1),
#  ('조심', 1),
#  ('스럽게', 1),
#  ('들어', 1),
#  ('올렸다', 1),
#  ('버리고', 1),
#  ('커졌다', 1),
#  ('본능', 1),
#  ('탐욕', 1),
#  ('이건', 1),
#  ('조차', 1),
#  ('놀랄', 1),
#  ('강력한', 1),
#  ('마치', 1),
#  ('불길', 1),
#  ('타오르는', 1),
#  ('연결하고', 1),
#  ('놀라서', 1),
#  ('물러났다', 1),
#  ('아르', 1),
#  ('비틀', 1),
#  ('급히', 1),
#  ('부축', 1),
#  ('괜찮아', 1),
#  ('너무나', 1),
#  ('폭풍', 1),
#  ('유지', 1),
#  ('없었던', 1),
#  ('끊어진', 1),
#  ('신경', 1),
#  ('쓰지', 1),
#  ('어어', 1),
#  ('갖고', 1),
#  ('있는', 1),
#  ('작고', 1),
#  ('오로지', 1),
#  ('에만', 1),
#  ('빼앗겼다', 1),
#  ('와라', 1),
#  ('빨아들이며', 1),
#  ('발동', 1),
#  ('막대', 1),
#  ('들어오자', 1),
#  ('격통', 1),
#  ('크으으', 1),
#  ('으윽', 1),
#  ('이마', 1),
#  ('팽팽', 1),
#  ('해져', 1),
#  ('튀어나왔고', 1),
#  ('강건', 1),
#  ('부들부들', 1),
#  ('떨렸다', 1),
#  ('포기', 1),
#  ('완성', 1),
#  ('시켰다', 1),
#  ('시커먼', 1),
#  ('뿜어져', 1),
#  ('숨결', 1),
#  ('통해', 1),
#  ('들어갔다', 1),
#  ('쿠르룽', 1),
#  ('왔다', 1),
#  ('동공', 1),
#  ('확장', 1),
#  ('안구', 1),
#  ('실핏줄', 1),
#  ('두드러지기', 1),
#  ('낯선', 1),
#  ('듯이', 1),
#  ('뛰고', 1),
#  ('혼란', 1),
#  ('스럽다', 1),
#  ('였는데', 1),
#  ('같은', 1),
#  ('아주', 1),
#  ('생소한', 1),
#  ('어리고', 1),
#  ('작던', 1),
#  ('시절', 1),
#  ('포식자', 1),
#  ('피해', 1),
#  ('다니며', 1),
#  ('느꼈던', 1),
#  ('떠올렸다', 1),
#  ('돌려', 1),
#  ('바다로', 1),
#  ('서두르지', 1),
#  ('아람', 1),
#  ('자존심', 1),
#  ('인지도', 1),
#  ('모른다', 1),
#  ('촤아아', 1),
#  ('담그자', 1),
#  ('일었다', 1),
#  ('난동', 1),
#  ('피운', 1),
#  ('거짓말', 1),
#  ('사라져', 1),
#  ('후우', 1),
#  ('성공한', 1),
#  ('안도', 1),
#  ('한숨', 1),
#  ('내쉬었다', 1),
#  ('인지', 1),
#  ('어느새', 1),
#  ('잿빛', 1),
#  ('딱딱한', 1),
#  ('덩이', 1),
#  ('변해있었다', 1),
#  ('바스스', 1),
#  ('허망', 1),
#  ('부서져', 1),
#  ('계획', 1),
#  ('어긋나는군', 1),
#  ('실패', 1),
#  ('아니지만', 1),
#  ('꼬여', 1),
#  ('설명', 1),
#  ('천지', 1),
#  ('누가', 1),
#  ('조종', 1),
#  ('있겠는가', 1),
#  ('빌어먹을', 1),
#  ('훨씬', 1),
#  ('덩치', 1),
#  ('처져', 1),
#  ('안색', 1),
#  ('어둡기', 1),
#  ('없다', 1),
#  ('문뜩', 1),
#  ('진창', 1),
#  ('잠깐', 1),
#  ('수천', 1),
#  ('용감했던', 1),
#  ('깨진', 1),
#  ('조각', 1),
#  ('굴러', 1),
#  ('다녔다', 1),
#  ('몰아내긴', 1),
#  ('누구', 1),
#  ('기뻐하지', 1),
#  ('보기', 1),
#  ('느긋하게', 1),
#  ('떠난', 1),
#  ('같았기', 1),
#  ('그저', 1),
#  ('명확한', 1),
#  ('자신', 1),
#  ('자랑', 1),
#  ('망치는', 1),
#  ('아무', 1),
#  ('일도', 1),
#  ('했다는', 1),
#  ('무언가', 1),
#  ('봤다', 1),
#  ('오히려', 1),
#  ('누군가', 1),
#  ('중얼거렸다', 1),
#  ('맞아', 1),
#  ('아니야', 1),
#  ('가슴', 1),
#  ('뜨겁게', 1),
#  ('달구는', 1),
#  ('반면', 1),
#  ('사악하고', 1),
#  ('불길해', 1),
#  ('보였다', 1),
#  ('쓴다는', 1),
#  ('소문', 1),
#  ('들었지만', 1),
#  ('믿지', 1),
#  ('오늘', 1),
#  ('이후', 1),
#  ('흉측하고', 1),
#  ('바르지', 1),
#  ('이야', 1),
#  ('어울리지', 1),
#  ('않아', 1),
#  ('쫓아냈음에도', 1),
#  ('승리', 1),
#  ('걱정스러운', 1),
#  ('대해', 1),
#  ('속삭일', 1),
#  ('따름이었다', 1),
#  ('끊긴', 1),
#  ('암담한', 1),
#  ('결과', 1),
#  ('사기', 1),
#  ('나락', 1),
#  ('떨어졌다', 1),
#  ('불행', 1),
#  ('그날', 1),
#  ('부터', 1),
#  ('매일', 1),
#  ('기사', 1),
#  ('습격', 1),
#  ('혈전', 1),
#  ('벌어지는', 1),
#  ('마침내', 1),
#  ('서퍽', 1),
#  ('공작', 1),
#  ('지원', 1),
#  ('출발', 1),
#  ('함선', 1),
#  ('나눠', 1),
#  ('탔다', 1),
#  ('여왕', 1),
#  ('남은', 1),
#  ('멀쩡한', 1),
#  ('했다고', 1),
#  ('군세', 1),
#  ('비해', 1),
#  ('많이', 1),
#  ('부족했으나', 1),
#  ('수송', 1),
#  ('능력', 1),
#  ('한계', 1),
#  ('대신', 1),
#  ('정예', 1),
#  ('꾸려졌다', 1),
#  ('거기', 1),
#  ('더해', 1),
#  ('매우', 1),
#  ('특별한', 1),
#  ('상태', 1),
#  ('나섰는데', 1),
#  ('애송이', 1),
#  ('벌써', 1),
#  ('나자빠져', 1),
#  ('있지', 1),
#  ('않았으면', 1),
#  ('좋겠군', 1),
#  ('흔들리는', 1),
#  ('전설', 1),
#  ('굵직한', 1),
#  ('목소리', 1),
#  ('크르르', 1),
#  ('걱정', 1),
#  ('없네', 1),
#  ('비범한', 1),
#  ('자는', 1),
#  ('쉽게', 1),
#  ('죽지', 1),
#  ('않는', 1),
#  ('이니까', 1),
#  ('놀랍게도', 1),
#  ('불패', 1),
#  ('군단', 1),
#  ('장이', 1),
#  ('영웅', 1),
#  ('찡그렸다', 1),
#  ('가게', 1),
#  ('됐잖아', 1),
#  ('어떻게', 1),
#  ('책임질', 1),
#  ('순전히', 1),
#  ('부탁', 1),
#  ('물어봤었다', 1),
#  ('은인', 1),
#  ('돕기', 1),
#  ('위해', 1),
#  ('가야겠다고', 1),
#  ('나선', 1),
#  ('펄쩍', 1),
#  ('뛰며', 1),
#  ('반대', 1),
#  ('은거', 1),
#  ('중인', 1),
#  ('도망자', 1),
#  ('주제', 1),
#  ('어딜', 1),
#  ('가냐는', 1),
#  ('완고한', 1),
#  ('고집', 1),
#  ('꺾을', 1),
#  ('고대', 1),
#  ('비밀', 1),
#  ('간직', 1),
#  ('있다네', 1),
#  ('않으면', 1),
#  ('도울', 1),
#  ('없어', 1),
#  ('알겠다고', 1),
#  ('그런데', 1),
#  ('끌려', 1),
#  ('솜씨', 1),
#  ('없다면', 1),
#  ('어찌', 1),
#  ('바구니', 1),
#  ('숨겠나', 1),
#  ('라는', 1),
#  ('이런', 1),
#  ('젠장', 1),
#  ('아까운', 1),
#  ('잖아', 1),
#  ('허허', 1),
#  ('평생', 1),
#  ('여러', 1),
#  ('왔지만', 1),
#  ('구두쇠', 1),
#  ('일세', 1),
#  ('작은', 1),
#  ('아까워서', 1),
#  ('벌벌', 1),
#  ('떠는', 1),
#  ('꼴은', 1),
#  ('신기하군', 1),
#  ('시끄러워', 1),
#  ('살아온', 1),
#  ('니까', 1),
#  ('투닥거릴', 1),
#  ('말쑥한', 1),
#  ('젊은이', 1),
#  ('독한', 1),
#  ('들이켜고', 1),
#  ('마그누스', 1),
#  ('남작', 1),
#  ('용병', 1),
#  ('이었던', 1),
#  ('자로', 1),
#  ('개조', 1),
#  ('끔찍한', 1),
#  ('당했었다', 1),
#  ('도움', 1),
#  ('돌아오게', 1),
#  ('연신', 1),
#  ('마시는', 1),
#  ('댔다', 1),
#  ('빠져', 1),
#  ('서는', 1),
#  ('따라온', 1),
#  ('지켜야', 1),
#  ('합니다', 1),
#  ('간단하게', 1),
#  ('모금', 1),
#  ('넘겼다', 1),
#  ('꿀꺽', 1),
#  ('돌아가는', 1),
#  ('대가', 1),
#  ('넘기기로', 1),
#  ('위험', 1),
#  ('무릅쓰', 1),
#  ('참여', 1),
#  ('의외', 1),
#  ('브리스', 1),
#  ('기다리고', 1),
#  ('있으면', 1),
#  ('되잖으냐', 1),
#  ('술독', 1),
#  ('빠진', 1),
#  ('레이', 1),
#  ('죽으면', 1),
#  ('지키잖습니까', 1),
#  ('황천', 1),
#  ('가기', 1),
#  ('있을', 1),
#  ('겁니다', 1),
#  ('호오', 1),
#  ('친절한', 1),
#  ('성격', 1),
#  ('지는', 1),
#  ('몰랐는데', 1),
#  ('그냥', 1),
#  ('찝찝한', 1),
#  ('싫을', 1),
#  ('뿐입니다', 1),
#  ('노인장', 1),
#  ('고쳐', 1),
#  ('고마운데', 1),
#  ('너무', 1),
#  ('친한', 1),
#  ('마십시오', 1),
#  ('귀찮습니다', 1),
#  ('뭐라', 1),
#  ('싸가지', 1),
#  ('바가지', 1),
#  ('해봐', 1),
#  ('새끼', 1),
#  ('원래', 1),
#  ('돌려놓을까', 1),
#  ('이렇게', 1),
#  ('모여있는', 1),
#  ('조용할', 1),
#  ('아까워하며', 1),
#  ('소리', 1),
#  ('나가지', 1),
#  ('시점', 1),
#  ('풍향', 1),
#  ('조류', 1),
#  ('바뀌고', 1),
#  ('있었기에', 1),
#  ('오래', 1),
#  ('걸렸다', 1),
#  ('일행', 1),
#  ('일주일', 1),
#  ('지난', 1),
#  ('에야', 1),
#  ('도착', 1),
#  ('와서', 1),
#  ('심각했다', 1),
#  ('밀려', 1),
#  ('드는', 1),
#  ('공세', 1),
#  ('함락', 1),
#  ('되고', 1),
#  ('방어', 1),
#  ('몰려있었던', 1),
#  ('궁지', 1),
#  ('몰린', 1),
#  ('몰아치고', 1),
#  ('갑판', 1),
#  ('보고', 1),
#  ('태연자약', 1),
#  ('뒤지지', 1),
#  ('않았으니까', 1),
#  ('도와주면', 1),
#  ('되겠지', 1),
#  ('쓸까', 1),
#  ('갸웃거렸다', 1),
#  ('바글', 1),
#  ('이었는데', 1),
#  ('대략', 1),
#  ('천명', 1),
#  ('넘는', 1),
#  ('싸움', 1),
#  ('열중', 1),
#  ('삽질', 1),
#  ('하잖아', 1),
#  ('건지', 1),
#  ('없었는데', 1),
#  ('열심히', 1),
#  ('내려가고', 1),
#  ('쌓아', 1),
#  ('올린', 1),
#  ('언덕', 1),
#  ('이루고', 1)]

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['font.size'] = 15
plt.rcParams['axes.unicode_minus'] =False

# %%
bar_label = df_emotion.columns[3:].values
index = np.arange(len(bar_label))

# %%
plt.figure(figsize=(20, 10))
plt.title('감정별 점수')
plt.xlabel('감정')
plt.ylabel('점수')
plt.grid(True)
p1 = plt.bar(index, novel_score, 0.35)
p2 = plt.bar(index + 0.35, song_score, 0.35)
plt.xticks(index, bar_label)
plt.legend((p1[0], p2[0]), ('소설', '노래'), fontsize=15)

# %%
wc = WordCloud(background_color ='white', colormap='autumn', font_path='malgun', width=250, height=250, scale=1.0, max_font_size=100)
gen = wc.generate_from_frequencies(novel_word_counts)
plt.figure(figsize=(10, 10))
plt.imshow(gen)
