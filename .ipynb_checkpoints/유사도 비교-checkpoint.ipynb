# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('data_files/노래별감정점수.csv')
df.head()
# Out:
#    Unnamed: 0                             노래                가수  슬픔  분노  기쁨  \
# 0           0                      사랑은 늘 도망가               임영웅   9   0   0
# 1           1                       코 끝이 찡하게               차가을   8   0   1
# 2           2                    혼자 사랑하고 미워해               백예슬   7   1   1
# 3           3  비 오는 날 듣기 좋은 노래 (Feat. Colde)  에픽하이 (EPIK HIGH)  19   2   5
# 4           4                    Your Lights        이수 (엠씨더맥스)   6   0   2
#
#    긴장감  무서운  증오  차분히  섹시  브릿락  설렘  몽환
# 0    1    0   0    0   2    0  11   4
# 1    0    0   0    0   0    1   4   1
# 2    0    0   2    0   2    0   6   0
# 3    2    0   3    1   1    0   5   0
# 4    0    0   2    0   1    0   3   1

# %%
emotion = df.drop(['Unnamed: 0', '노래', '가수'], axis=1)

# %%
a = [20, 10, 15, 13, 4, 6, 3, 5, 4, 3, 6]

# %%
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * (np.linalg.norm(b)))

# %%
emotion.iloc[0, :].values
# Out:
# array([ 9,  0,  0,  1,  0,  0,  0,  2,  0, 11,  4], dtype=int64)

# %%
def search_similarity(a):
    similarity_li = []
    for i in range(len(emotion)):
        b = emotion.iloc[i, :].values
        similarity_li.append(cosine_similarity(a, b))
    print(np.argmax(similarity_li))
    title = df.iloc[np.argmax(similarity_li), 1]
    singer = df.iloc[np.argmax(similarity_li), 2]
    return f"{singer} - {title}"

# %%
search_similarity(a)
# Out:
# 21
# '에픽하이 (EPIK HIGH) - Rosario (Feat. CL, ZICO)'

# %%
df.iloc[21, :]
# Out:
# 노래     ('Rosario (Feat. CL, ZICO)', 'Sam Smith')
# 슬픔                                             9
# 분노                                             3
# 기쁨                                             6
# 긴장감                                            3
# 무서운                                            1
# 증오                                             1
# 차분히                                            1
# 섹시                                             2
# 브릿락                                            1
# 설렘                                             1
# 몽환                                             2
# Name: 21, dtype: object

# %%
df = pd.read_csv('data_files/ok_song.csv')
df.head()
# Out:
#    Unnamed: 0                             노래                가수  \
# 0           0                      사랑은 늘 도망가               임영웅
# 1           1                       코 끝이 찡하게               차가을
# 2           2                    혼자 사랑하고 미워해               백예슬
# 3           3  비 오는 날 듣기 좋은 노래 (Feat. Colde)  에픽하이 (EPIK HIGH)
# 4           4                    Your Lights        이수 (엠씨더맥스)
#
#                                                   가사
# 0  \r\n\t\t\t\t\t\t\t눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생...
# 1  \r\n\t\t\t\t\t\t\t오랜만에 친구를 만나이런저런 얘기를 나눴어얼굴이 안...
# 2  \r\n\t\t\t\t\t\t\t흐린 새벽에 무심히 핸드폰 속가만히 들여다보면너와 ...
# 3  \r\n\t\t\t\t\t\t\t비가 오고네가 생각나비가 오고또 비가 오고슬픈 음악...
# 4  \r\n\t\t\t\t\t\t\t나는 흙으로부터 왔고다시금 그리 가겠지한낱 그런 삶...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#                                 노래                 가수  \
# 0                        사랑은 늘 도망가                임영웅
# 1                         코 끝이 찡하게                차가을
# 2                      혼자 사랑하고 미워해                백예슬
# 3    비 오는 날 듣기 좋은 노래 (Feat. Colde)   에픽하이 (EPIK HIGH)
# 4                      Your Lights         이수 (엠씨더맥스)
# ..                             ...                ...
# 476                          Faded        Alan Walker
# 477                        혼자라는 느낌  이상은 (=Lee-tzsche)
# 478                      재와 연기의 노래            못 (Mot)
# 479                        Scenery     Ashmute (애쉬뮤트)
# 480               엘리베이터 (Elevator)      종현 (JONGHYUN)
#
#                                                     가사
# 0    \r\n\t\t\t\t\t\t\t눈물이 난다 이 길을 걸으면그 사람 손길이 자꾸 생...
# 1    \r\n\t\t\t\t\t\t\t오랜만에 친구를 만나이런저런 얘기를 나눴어얼굴이 안...
# 2    \r\n\t\t\t\t\t\t\t흐린 새벽에 무심히 핸드폰 속가만히 들여다보면너와 ...
# 3    \r\n\t\t\t\t\t\t\t비가 오고네가 생각나비가 오고또 비가 오고슬픈 음악...
# ...

# %%
pd.read_csv('data_files/songnsinger.csv')
# Out:
#                                 노래                 가수  슬픔  분노  기쁨  긴장감  무서운  \
# 0                        사랑은 늘 도망가                임영웅   9   0   0    1    0
# 1                         코 끝이 찡하게                차가을   8   0   1    0    0
# 2                      혼자 사랑하고 미워해                백예슬   7   1   1    0    0
# 3    비 오는 날 듣기 좋은 노래 (Feat. Colde)   에픽하이 (EPIK HIGH)  19   2   5    2    0
# 4                      Your Lights         이수 (엠씨더맥스)   6   0   2    0    0
# ..                             ...                ...  ..  ..  ..  ...  ...
# 476                          Faded        Alan Walker   0   0   0    0    0
# 477                        혼자라는 느낌  이상은 (=Lee-tzsche)   5   0   0    2    0
# 478                      재와 연기의 노래            못 (Mot)   4   0   2    0    0
# 479                        Scenery     Ashmute (애쉬뮤트)  10   0   0    0    0
# 480               엘리베이터 (Elevator)      종현 (JONGHYUN)   1   0   0    0    0
#
#      증오  차분히  섹시  브릿락  설렘  몽환
# ...

# %%
df_emotion.노래 = df.가수

# %%
df.가수
# Out:
# 0                    임영웅
# 1                    차가을
# 2                    백예슬
# 3       에픽하이 (EPIK HIGH)
# 4             이수 (엠씨더맥스)
#              ...
# 476          Alan Walker
# 477    이상은 (=Lee-tzsche)
# 478              못 (Mot)
# 479       Ashmute (애쉬뮤트)
# 480        종현 (JONGHYUN)
# Name: 가수, Length: 481, dtype: object

# %%
df_emotion['가수'] = df.가수

# %%
df_emotion = df_emotion[['노래', '가수', '슬픔', '분노', '기쁨', '긴장감', '무서운', '증오', '차분히', '섹시', '브릿락', '설렘', '몽환']]

# %%
df_emotion.to_csv('data_files/노래별감정점수.csv')
